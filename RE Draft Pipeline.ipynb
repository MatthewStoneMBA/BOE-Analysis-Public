# %%
# Never install the pip install googlesearch-python python package — instead install 
from googlesearch import search # get zpid — the ID for a Zillow search (Unique zillow identifier)

import pandas as pd
import requests
import json
import time
import io
import plotly.express as px


pd.set_option('display.max_columns', None)

rapid_api_key = "0cbb9aa5d6msheae35e6a3553235p18f957jsne70c9048c637"
rapid_api_host = "zillow-com1.p.rapidapi.com"

# %%
# property address


property_address = '3830 18th Avenue SW, Seattle, WA 98106' # https://www.zillow.com/homedetails/3830-18th-Ave-SW-Seattle-WA-98106/49044708_zpid/

# search query
query = property_address + ' zillow home details'
print('Search this phrase in Google Search:', query)
# Out:
# Search this phrase in Google Search: 3830 18th Avenue SW, Seattle, WA 98106 zillow home details

# %%
# google search results
search_results = search(query, tld='com', lang='en', num=3, start=0, stop=3, pause=0)

search_results_list = [u for u in search_results] # get all results
search_results_list
# Out:
# ['https://www.zillow.com/homedetails/3830-18th-Ave-SW-Seattle-WA-98106/49044708_zpid/',
#  'https://www.trulia.com/p/wa/seattle/3830-18th-ave-sw-seattle-wa-98106--2118688341',
#  'https://www.redfin.com/WA/Seattle/3830-18th-Ave-SW-98106/home/160357']

# %%
# Extract the first result

url = search_results_list[0]

url
# Out:
# 'https://www.zillow.com/homedetails/3830-18th-Ave-SW-Seattle-WA-98106/49044708_zpid/'

# %%
# Extracting ZPID from that search 
    # For Loop

zpid = [x for x in url.split('/') if 'zpid' in x][0].split('_')[0]
print('Property Zpid ——', zpid)
# Out:
# Property Zpid —— 49044708

# %%
url = "https://zillow-com1.p.rapidapi.com/property"

querystring = {"zpid":zpid}

headers = {
	"X-RapidAPI-Key": rapid_api_key,
	"X-RapidAPI-Host": rapid_api_host
}

response = requests.request("GET", url, headers=headers, params=querystring)

response.status_code # 200 is success!
# Out:
# 200

# %%
response.json()
# Out:
# {'listingProvider': None,
#  'buildingPermits': None,
#  'propertyTaxRate': 1.01,
#  'contact_recipients': [{'agent_reason': 1,
#    'zpro': None,
#    'recent_sales': 0,
#    'review_count': 92,
#    'display_name': 'Laura Papritz',
#    'zuid': 'X1-ZUyxxb6j0pc3d5_5cfwe',
#    'rating_average': 4.9,
#    'badge_type': 'Premier Agent',
#    'phone': {'prefix': '203', 'areacode': '206', 'number': '2391'},
#    'image_url': 'https://photos.zillowstatic.com/h_n/ISzjd7hbgsm1v80000000000.jpg'}],
#  'solarPotential': {'sunScore': 60.39,
#   'solarFactor': 2.32,
#   'buildFactor': 50.4,
#   'climateFactor': 5.84,
#   'electricityFactor': 1.83},
#  'longitude': -122.35654,
#  'countyFIPS': '53033',
#  'cityId': 16037,
#  'timeOnZillow': '131 days',
#  'url': '/homedetails/3830-18th-Ave-SW-Seattle-WA-98106/49044708_zpid/',
#  'zestimate': 774400,
#  'imgSrc': 'https://photos.zillowstatic.com/fp/f7d48160e7b024c171fefa55fe0e087d-p_d.jpg',
#  'zpid': 49044708,
#  'zipcode': '98106',
#  'livingAreaValue': 1900,
#  'zestimateLowPercent': '8',
#  'isListedByOwner': False,
#  'propertyTypeDimension': 'Single Family',
#  'resoFacts': {'hasAttachedProperty': False,
#   'frontageType': None,
#   'poolFeatures': None,
#   'flooring': ['Ceramic Tile', 'Vinyl', 'Carpet', 'Wall to Wall Carpet'],
#   'foundationDetails': ['Poured Concrete'],
#   'accessibilityFeatures': None,
#   'hasGarage': False,
#   'hasPetsAllowed': None,
#   'bodyType': None,
#   'topography': 'Level,SteepSlope',
#   'landLeaseExpirationDate': None,
#   'hasAdditionalParcels': False,
#   'waterViewYN': True,
#   'atAGlanceFacts': [{'factLabel': 'Type',
#     'factValue': 'Single Family Residence'},
#    {'factLabel': 'Year Built', 'factValue': '1959'},
#    {'factLabel': 'Heating', 'factValue': 'Forced Air, Wall'},
#    {'factLabel': 'Cooling', 'factValue': 'Forced Air, Wall'},
#    {'factLabel': 'Parking', 'factValue': 'None'},
#    {'factLabel': 'Lot', 'factValue': '5,000 sqft'},
#    {'factLabel': 'Days on Zillow', 'factValue': '131 Days'},
#    {'factLabel': 'Price/sqft', 'factValue': '$379'},
#    {'factLabel': "Buyer's Agent Fee", 'factValue': '3'},
#    {'factLabel': 'Offer Review Date', 'factValue': None}],
#   'offerReviewDate': None,
#   'aboveGradeFinishedArea': None,
#   'view': ['Bay', 'Canal', 'Sound'],
#   'buyerAgencyCompensationType': '%',
#   'rooms': [{'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomFeatures': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomLength': None,
#     'width': None,
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': 'Main',
#     'roomLengthWidthUnits': None,
#     'roomLengthWidthSource': None,
#     'roomDimensions': None,
#     'roomAreaUnits': None,
#     'roomType': 'Bedroom',
#     'length': None,
#     'description': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomFeatures': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomLength': None,
#     'width': None,
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': 'Lower',
#     'roomLengthWidthUnits': None,
#     'roomLengthWidthSource': None,
#     'roomDimensions': None,
#     'roomAreaUnits': None,
#     'roomType': 'Bedroom',
#     'length': None,
#     'description': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomFeatures': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomLength': None,
#     'width': None,
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': 'Main',
#     'roomLengthWidthUnits': None,
#     'roomLengthWidthSource': None,
#     'roomDimensions': None,
#     'roomAreaUnits': None,
#     'roomType': None,
#     'length': None,
#     'description': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomFeatures': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomLength': None,
#     'width': None,
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': 'Lower',
#     'roomLengthWidthUnits': None,
#     'roomLengthWidthSource': None,
#     'roomDimensions': None,
#     'roomAreaUnits': None,
#     'roomType': None,
#     'length': None,
#     'description': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomFeatures': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomLength': None,
#     'width': None,
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': 'Main',
#     'roomLengthWidthUnits': None,
#     'roomLengthWidthSource': None,
#     'roomDimensions': None,
#     'roomAreaUnits': None,
#     'roomType': 'LivingRoom',
#     'length': None,
#     'description': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomFeatures': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomLength': None,
#     'width': None,
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': 'Main',
#     'roomLengthWidthUnits': None,
#     'roomLengthWidthSource': None,
#     'roomDimensions': None,
#     'roomAreaUnits': None,
#     'roomType': None,
#     'length': None,
#     'description': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomFeatures': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomLength': None,
#     'width': None,
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': 'Main',
#     'roomLengthWidthUnits': None,
#     'roomLengthWidthSource': None,
#     'roomDimensions': None,
#     'roomAreaUnits': None,
#     'roomType': 'DiningRoom',
#     'length': None,
#     'description': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomFeatures': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomLength': None,
#     'width': None,
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': 'Main',
#     'roomLengthWidthUnits': None,
#     'roomLengthWidthSource': None,
#     'roomDimensions': None,
#     'roomAreaUnits': None,
#     'roomType': 'Bedroom',
#     'length': None,
#     'description': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomFeatures': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomLength': None,
#     'width': None,
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': 'Lower',
#     'roomLengthWidthUnits': None,
#     'roomLengthWidthSource': None,
#     'roomDimensions': None,
#     'roomAreaUnits': None,
#     'roomType': 'Bedroom',
#     'length': None,
#     'description': None,
#     'area': None},
#    {'level': None,
#     'dimensions': None,
#     'features': None,
#     'roomFeatures': None,
#     'roomArea': None,
#     'roomAreaSource': None,
#     'roomLength': None,
#     'width': None,
#     'roomDescription': None,
#     'roomWidth': None,
#     'roomLevel': 'Lower',
#     'roomLengthWidthUnits': None,
#     'roomLengthWidthSource': None,
#     'roomDimensions': None,
#     'roomAreaUnits': None,
#     'roomType': 'Bedroom',
#     'length': None,
#     'description': None,
#     'area': None}],
#   'carportSpaces': None,
#   'cityRegion': 'Seattle',
#   'mainLevelBathrooms': None,
#   'hasPrivatePool': None,
#   'associationFeeIncludes': None,
#   'waterSource': ['Public', 'Company: Seattle'],
#   'exteriorFeatures': {},
#   'coveredSpaces': 0,
#   'inclusions': ['Dishwasher', 'Refrigerator', 'StoveRange'],
#   'hasFireplace': False,
#   'zoningDescription': None,
#   'garageSpaces': None,
#   'sewer': ['Sewer Connected', 'Company: Seattle'],
#   'elevationUnits': 'Feet',
#   'exclusions': None,
#   'mainLevelBedrooms': 2,
#   'numberOfUnitsVacant': None,
#   'hasWaterfrontView': None,
#   'listAOR': None,
#   'lotSize': '5,000 sqft',
#   'entryLevel': None,
#   'irrigationWaterRightsAcres': None,
#   'greenWaterConservation': None,
#   'stories': 1,
#   'livingArea': '1,900 sqft',
#   'numberOfUnitsInCommunity': None,
#   'listingTerms': 'Cash Out,Conventional,FHA,VA Loan',
#   'otherStructures': None,
#   'associationFee': None,
#   'marketingType': None,
#   'greenIndoorAirQuality': None,
#   'greenSustainability': None,
#   'hasHomeWarranty': False,
#   'associationPhone': None,
#   'greenBuildingVerificationType': None,
#   'elementarySchool': None,
#   'bedrooms': 5,
#   'architecturalStyle': None,
#   'listingId': None,
#   'structureType': 'House',
#   'interiorFeatures': None,
#   'horseAmenities': None,
#   'electric': ['Company: Seattle Electric'],
#   'developmentStatus': None,
#   'lotFeatures': ['Dead End Street',
#    'Paved',
#    'Cable TV',
#    'Deck',
#    'Fenced-Fully',
#    'High Speed Internet'],
#   'roofType': 'Composition',
#   'waterSources': None,
#   'constructionMaterials': ['Wood Products'],
#   'fireplaceFeatures': None,
#   'doorFeatures': None,
#   'appliances': ['Dishwasher', 'Refrigerator', 'Stove/Range'],
#   'daysOnZillow': 131,
#   'bathroomsPartial': None,
#   'bathroomsHalf': 0,
#   'depositsAndFees': None,
#   'canRaiseHorses': False,
#   'buildingName': None,
#   'hasAssociation': None,
#   'petsMaxWeight': None,
#   'commonWalls': None,
#   'totalActualRent': None,
#   'additionalParcelsDescription': None,
#   'associationName': None,
#   'allowedPets': None,
#   'communityFeatures': None,
#   'tenantPays': None,
#   'middleOrJuniorSchool': None,
#   'lotSizeDimensions': None,
#   'roadSurfaceType': None,
#   'hasOpenParking': False,
#   'yearBuilt': 1959,
#   'livingAreaRangeUnits': None,
#   'irrigationWaterRightsYN': False,
#   'bathroomsFull': 2,
#   'horseYN': None,
#   'incomeIncludes': None,
#   'highSchool': None,
#   'leaseTerm': None,
#   'elevation': None,
#   'cropsIncludedYN': None,
#   'attic': None,
#   'subdivisionName': 'Pigeon Point',
#   'windowFeatures': None,
#   'ownership': None,
#   'woodedArea': None,
#   'middleOrJuniorSchoolDistrict': None,
#   'associationPhone2': None,
#   'buyerAgencyCompensation': '3',
#   'heating': ['Forced Air', 'Wall'],
#   'frontageLength': None,
#   'virtualTourURLUnbranded': None,
#   'associationAmenities': None,
#   'propertySubType': ['Single Family Residence'],
#   'hasCooling': True,
#   'belowGradeFinishedArea': None,
#   'hasElectricOnProperty': None,
#   'foundationArea': None,
#   'zoning': None,
#   'hoaFee': None,
#   'livingAreaRange': None,
#   'basementYN': False,
#   'availabilityDate': None,
#   'waterBodyName': None,
#   'waterfrontFeatures': None,
#   'specialListingConditions': 'Standard',
#   'buildingAreaSource': None,
#   'taxAnnualAmount': 5980,
#   'parking': 0,
#   'hasView': True,
#   'virtualTour': None,
#   'securityFeatures': None,
#   'cooling': ['Forced Air', 'Wall'],
#   'entryLocation': None,
#   'otherFacts': {},
#   'levels': 'One',
#   'ownershipType': None,
#   'basement': 'Finished',
#   'onMarketDate': 1649721600000,
#   'waterView': 'Bay,Canal,Sound',
#   'laundryFeatures': None,
#   'hasAttachedGarage': False,
#   'fencing': None,
#   'spaFeatures': None,
#   'bathrooms': 2,
#   'homeType': 'SingleFamily',
#   'isSeniorCommunity': None,
#   'municipality': None,
#   'bathroomsThreeQuarter': 0,
#   'hasSpa': False,
#   'otherParking': None,
#   'associationFee2': None,
#   'parcelNumber': '7547300800',
#   'hasHeating': True,
#   'associationName2': None,
#   'hasRentControl': None,
#   'elementarySchoolDistrict': None,
#   'otherEquipment': None,
#   'parkingFeatures': ['None'],
#   'buildingArea': '1,900',
#   'furnished': False,
#   'vegetation': None,
#   'patioAndPorchFeatures': None,
#   'buildingFeatures': None,
#   'builderName': None,
#   'highSchoolDistrict': 'Seattle',
#   'propertyCondition': None,
#   'storiesTotal': None,
#   'yearBuiltEffective': None,
#   'fireplaces': None,
#   'bathroomsOneQuarter': None,
#   'builderModel': None,
#   'gas': None,
#   'utilities': ['Cable Connected',
#    'High Speed Internet',
#    'Sewer Connected',
#    'Electricity Available'],
#   'greenEnergyEfficient': None,
#   'landLeaseAmount': None,
#   'isNewConstruction': None,
#   'hasLandLease': False,
#   'pricePerSquareFoot': 379,
#   'hasCarport': False,
#   'openParkingSpaces': None},
#  'streetAddress': '3830 18th Avenue SW',
#  'county': None,
#  'taxHistory': [{'time': 1630726505420,
#    'valueIncreaseRate': 0.109375,
#    'taxIncreaseRate': 0.05212827,
#    'taxPaid': 6292.19,
#    'value': 639000},
#   {'time': 1599190505420,
#    'valueIncreaseRate': 0.023090586,
#    'taxIncreaseRate': 0.036216393,
#    'taxPaid': 5980.44,
#    'value': 576000},
#   {'time': 1567568105420,
#    'valueIncreaseRate': 0.023636363,
#    'taxIncreaseRate': 0.13422188,
#    'taxPaid': 5771.42,
#    'value': 563000},
#   {'time': 1536032105420,
#    'valueIncreaseRate': 0.2195122,
#    'taxIncreaseRate': 0.058770347,
#    'taxPaid': 5088.44,
#    'value': 550000},
#   {'time': 1504496105420,
#    'valueIncreaseRate': 0.13032581,
#    'taxIncreaseRate': 0.5840181,
#    'taxPaid': 4805.99,
#    'value': 451000},
#   {'time': 1472960105420,
#    'valueIncreaseRate': 0.18047337,
#    'taxIncreaseRate': 0,
#    'taxPaid': 3034.05,
#    'value': 399000},
#   {'time': 1441337705420,
#    'valueIncreaseRate': 0.1736111,
#    'taxIncreaseRate': 0,
#    'taxPaid': 3034.05,
#    'value': 338000},
#   {'time': 1409801705420,
#    'valueIncreaseRate': 0.2576419,
#    'taxIncreaseRate': 0,
#    'taxPaid': 3034.05,
#    'value': 288000},
#   {'time': 1378265705420,
#    'valueIncreaseRate': 0.013274336,
#    'taxIncreaseRate': 0,
#    'taxPaid': 3034.05,
#    'value': 229000},
#   {'time': 1346729705420,
#    'valueIncreaseRate': -0.0996016,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 226000},
#   {'time': 1315107305420,
#    'valueIncreaseRate': -0.059925094,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 251000},
#   {'time': 1283571305420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 267000},
#   {'time': 1252035305420,
#    'valueIncreaseRate': 0.2961165,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 267000},
#   {'time': 1188876905420,
#    'valueIncreaseRate': 0.06735751,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 206000},
#   {'time': 1157340905420,
#    'valueIncreaseRate': 0.03208556,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 193000},
#   {'time': 1125804905420,
#    'valueIncreaseRate': 0.6846847,
#    'taxIncreaseRate': 0,
#    'taxPaid': None,
#    'value': 187000},
#   {'time': 999574505420,
#    'valueIncreaseRate': 0.121212125,
#    'taxIncreaseRate': 0.07212835,
#    'taxPaid': 1375.68,
#    'value': 111000},
#   {'time': 968038505420,
#    'valueIncreaseRate': 0,
#    'taxIncreaseRate': 0,
#    'taxPaid': 1283.13,
#    'value': 99000}],
#  'stateId': 59,
#  'countyId': 207,
#  'timeZone': 'America/Los_Angeles',
#  'homeType': 'SINGLE_FAMILY',
#  'livingAreaUnits': 'sqft',
#  'comingSoonOnMarketDate': None,
#  'livingArea': 1900,
#  'bathrooms': 2,
#  'annualHomeownersInsurance': 3024,
#  'state': 'WA',
#  'rentZestimate': 3200,
#  'building': None,
#  'brokerId': None,
#  'yearBuilt': 1959,
#  'brokerageName': 'Four-U Realty Inc',
#  'dateSold': '2006-09-01',
#  'price': 720000,
#  'pageViewCount': 2581,
#  'description': 'PRIVATE, West Seattle location in Pigeon Point, just minutes from Alkai Beach and downtown! Partial views of Duwamish Waterway make this setting complete. Located off a quiet, dead-end street with two off-street parking spaces, this 5 bedroom, 2 bath home is waiting for you! The home is already updated and ready to enjoy. Fully fenced yard and decks give plenty of outdoor living space. Make this your home or invest in a rental. Current rental use, month to month, tenants will be out prior to close. Seller states there will be fresh paint, new appliances, and new carpet/flooring prior to close also!',
#  'mortgageRates': {'arm5Rate': 4.876,
#   'fifteenYearFixedRate': 4.719,
#   'thirtyYearFixedRate': 5.499},
#  'homeStatus': 'FOR_SALE',
#  'homeFacts': None,
#  'latitude': 47.569202,
#  'datePosted': '2022-04-25',
#  'bedrooms': 5,
#  'nearbyHomes': [{'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/89a2bdeab3056fe00ac69470671b3195-p_c.jpg'}],
#    'zpid': 49044720,
#    'longitude': -122.35622,
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '3831 17th Ave SW',
#     'zipcode': '98106'},
#    'price': 648000,
#    'homeType': 'MULTI_FAMILY',
#    'homeStatus': 'SOLD',
#    'currency': 'USD',
#    'latitude': 47.56922},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/e0d2f74de0f4317b6e72ac46b8ff7df5-p_c.jpg'}],
#    'zpid': 49044721,
#    'longitude': -122.35622,
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '3827 17th Ave SW',
#     'zipcode': '98106'},
#    'price': 718600,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 47.569324},
#   {'miniCardPhotos': [{'url': 'https://maps.googleapis.com/maps/api/streetview?location=3835+17th+Ave+SW%2C+Seattle%2C+WA+98106&size=316x234&key=AIzaSyARFMLB1na-BBWf7_R3-5YOQQaHqEJf6RQ&source=outdoor&&signature=CgnAEqukYQU-DPoqG5Uq1hr-Jag='}],
#    'zpid': 49044719,
#    'longitude': -122.35615,
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '3835 17th Ave SW',
#     'zipcode': '98106'},
#    'price': 1098000,
#    'homeType': 'MULTI_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 47.569103},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/085cec42d480327a2e40da4d30ff7634-p_c.jpg'}],
#    'zpid': 49044710,
#    'longitude': -122.35663,
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '3840 18th Ave SW',
#     'zipcode': '98106'},
#    'price': 663250,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'SOLD',
#    'currency': 'USD',
#    'latitude': 47.568897},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/f4e99ecf7f67ec8803500e632a7a810b-p_c.jpg'}],
#    'zpid': 49044718,
#    'longitude': -122.356224,
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '3837 17th Ave SW',
#     'zipcode': '98106'},
#    'price': 735000,
#    'homeType': 'MULTI_FAMILY',
#    'homeStatus': 'RECENTLY_SOLD',
#    'currency': 'USD',
#    'latitude': 47.56895},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/ba56054b008e930d633836da273613dc-p_c.jpg'}],
#    'zpid': 49044722,
#    'longitude': -122.35624,
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '3823 17th Ave SW',
#     'zipcode': '98106'},
#    'price': 424600,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'OTHER',
#    'currency': 'USD',
#    'latitude': 47.56949},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/9109c0fbdf33f1aeb5886318928aeb9d-p_c.jpg'}],
#    'zpid': 66650845,
#    'longitude': -122.35612,
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '3825 17th Ave SW',
#     'zipcode': '98106'},
#    'price': 650000,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'SOLD',
#    'currency': 'USD',
#    'latitude': 47.56943},
#   {'miniCardPhotos': [{'url': 'https://photos.zillowstatic.com/fp/116221cb2567eba306e2b2403f351325-p_c.jpg'}],
#    'zpid': 49044717,
#    'longitude': -122.356224,
#    'address': {'city': 'Seattle',
#     'state': 'WA',
#     'streetAddress': '3843 17th Ave SW',
#     'zipcode': '98106'},
#    'price': 450000,
#    'homeType': 'SINGLE_FAMILY',
#    'homeStatus': 'RECENTLY_SOLD',
#    'currency': 'USD',
#    'latitude': 47.56886}],
#  'monthlyHoaFee': None,
#  'priceHistory': [{'priceChangeRate': -0.013698630136986,
#    'date': '2022-06-13',
#    'source': 'NWMLS',
#    'postingIsRental': False,
#    'time': 1655078400000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'NWMLS',
#     'infoString3': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_logo_inf_11.jpg',
#     'infoString1': '1915605'},
#    'pricePerSquareFoot': 379,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 720000},
#   {'priceChangeRate': -0.013513513513514,
#    'date': '2022-05-17',
#    'source': 'NWMLS',
#    'postingIsRental': False,
#    'time': 1652745600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'NWMLS',
#     'infoString3': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_logo_inf_11.jpg',
#     'infoString1': '1915605'},
#    'pricePerSquareFoot': 384,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 730000},
#   {'priceChangeRate': -0.013333333333333,
#    'date': '2022-05-12',
#    'source': 'NWMLS',
#    'postingIsRental': False,
#    'time': 1652313600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'NWMLS',
#     'infoString3': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_logo_inf_11.jpg',
#     'infoString1': '1915605'},
#    'pricePerSquareFoot': 389,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 740000},
#   {'priceChangeRate': -0.0625,
#    'date': '2022-04-23',
#    'source': 'NWMLS',
#    'postingIsRental': False,
#    'time': 1650672000000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'NWMLS',
#     'infoString3': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_logo_inf_11.jpg',
#     'infoString1': '1915605'},
#    'pricePerSquareFoot': 395,
#    'buyerAgent': None,
#    'event': 'Price change',
#    'price': 750000},
#   {'priceChangeRate': 2.2,
#    'date': '2022-04-12',
#    'source': 'NWMLS',
#    'postingIsRental': False,
#    'time': 1649721600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'NWMLS',
#     'infoString3': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_logo_inf_11.jpg',
#     'infoString1': '1915605'},
#    'pricePerSquareFoot': 421,
#    'buyerAgent': None,
#    'event': 'Listed for sale',
#    'price': 800000},
#   {'priceChangeRate': 0,
#    'date': '2020-07-08',
#    'source': 'Four-U Realty Inc',
#    'postingIsRental': True,
#    'time': 1594166400000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Four-U Realty Inc',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': None,
#    'buyerAgent': None,
#    'event': 'Listing removed',
#    'price': 3500},
#   {'priceChangeRate': 0,
#    'date': '2020-05-27',
#    'source': 'Four-U Realty Inc',
#    'postingIsRental': True,
#    'time': 1590537600000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'Four-U Realty Inc',
#     'infoString3': None,
#     'infoString1': None},
#    'pricePerSquareFoot': None,
#    'buyerAgent': None,
#    'event': 'Listed for rent',
#    'price': 3500},
#   {'priceChangeRate': 0,
#    'date': '2006-09-01',
#    'source': 'NWMLS',
#    'postingIsRental': False,
#    'time': 1157068800000,
#    'sellerAgent': None,
#    'showCountyLink': False,
#    'attributeSource': {'infoString2': 'NWMLS',
#     'infoString3': 'https://photos.zillowstatic.com/fp/9a447f16dd3203b8d030db7116cea37e-zillow_web_logo_inf_11.jpg',
#     'infoString1': '26073164'},
#    'pricePerSquareFoot': 132,
#    'buyerAgent': None,
#    'event': 'Sold',
#    'price': 250000}],
#  'favoriteCount': 15,
#  'schools': [{'link': 'https://www.greatschools.org/school?id=03226&state=WA',
#    'rating': 7,
#    'totalCount': 3,
#    'distance': 0.4,
#    'assigned': None,
#    'name': 'Pathfinder K-8',
#    'studentsPerTeacher': 15,
#    'isAssigned': True,
#    'size': 488,
#    'level': 'Elementary',
#    'grades': 'K-8',
#    'type': 'Public'},
#   {'link': 'https://www.greatschools.org/school?id=01617&state=WA',
#    'rating': 6,
#    'totalCount': 1,
#    'distance': 1.8,
#    'assigned': None,
#    'name': 'West Seattle High School',
#    'studentsPerTeacher': 21,
#    'isAssigned': True,
#    'size': 1029,
#    'level': 'High',
#    'grades': '9-12',
#    'type': 'Public'}],
#  'zestimateHighPercent': '8',
#  'mlsid': '1915605',
#  'address': {'city': 'Seattle',
#   'neighborhood': None,
#   'state': 'WA',
#   'streetAddress': '3830 18th Avenue SW',
#   'zipcode': '98106'},
#  'city': 'Seattle',
#  'providerListingID': None,
#  'country': 'USA',
#  'currency': 'USD',
#  'listed_by': {'agent_reason': 3,
#   'zpro': True,
#   'recent_sales': 1,
#   'review_count': 9,
#   'display_name': 'Erin McNulty',
#   'badge_type': 'Listing Agent',
#   'business_name': 'Four-U Realty Inc',
#   'rating_average': 5,
#   'phone': {'prefix': '525', 'areacode': '253', 'number': '5378'},
#   'zuid': 'X1-ZUwntcarytun0p_1wtuu',
#   'image_url': 'https://photos.zillowstatic.com/h_n/IS6a7qqncytgim0000000000.jpg'},
#  'contingentListingType': None}

# %%
df_property_detail = pd.json_normalize(data=response.json())
print('# of Rows:', len(df_property_detail))
print('# of Columns', len(df_property_detail.columns))
df_property_detail.head()
# Out:
# # of Rows: 1
# # of Columns 259
#   listingProvider buildingPermits  propertyTaxRate  \
# 0            None            None             1.01
#
#                                   contact_recipients  longitude countyFIPS  \
# 0  [{'agent_reason': 1, 'zpro': None, 'recent_sal... -122.35654      53033
#
#    cityId timeOnZillow                                                url  \
# 0   16037     131 days  /homedetails/3830-18th-Ave-SW-Seattle-WA-98106...
#
#    zestimate                                             imgSrc      zpid  \
# 0     774400  https://photos.zillowstatic.com/fp/f7d48160e7b...  49044708
#
#   zipcode  livingAreaValue zestimateLowPercent  isListedByOwner  \
# 0   98106             1900                   8            False
#
#   propertyTypeDimension        streetAddress county  \
# 0         Single Family  3830 18th Avenue SW   None
#
#                                           taxHistory  stateId  countyId  \
# 0  [{'time': 1630726505420, 'valueIncreaseRate': ...       59       207
#
#               timeZone       homeType livingAreaUnits comingSoonOnMarketDate  \
# 0  America/Los_Angeles  SINGLE_FAMILY            sqft                   None
#
#    livingArea  bathrooms  annualHomeownersInsurance state  rentZestimate  \
# 0        1900          2                       3024    WA           3200
#
#   building brokerId  yearBuilt      brokerageName    dateSold   price  \
# 0     None     None       1959  Four-U Realty Inc  2006-09-01  720000
#
#    pageViewCount                                        description  \
# 0           2581  PRIVATE, West Seattle location in Pigeon Point...
#
#   homeStatus homeFacts   latitude  datePosted  bedrooms  \
# 0   FOR_SALE      None  47.569202  2022-04-25         5
#
#                                          nearbyHomes monthlyHoaFee  \
# 0  [{'miniCardPhotos': [{'url': 'https://photos.z...          None
#
#                                         priceHistory  favoriteCount  \
# 0  [{'priceChangeRate': -0.013698630136986, 'date...             15
#
#                                              schools zestimateHighPercent  \
# 0  [{'link': 'https://www.greatschools.org/school...                    8
#
#      mlsid     city providerListingID country currency contingentListingType  \
# 0  1915605  Seattle              None     USA      USD                  None
#
#    solarPotential.sunScore  solarPotential.solarFactor  \
# 0                    60.39                        2.32
#
#    solarPotential.buildFactor  solarPotential.climateFactor  \
# 0                        50.4                          5.84
#
#    solarPotential.electricityFactor  resoFacts.hasAttachedProperty  \
# 0                              1.83                          False
#
#   resoFacts.frontageType resoFacts.poolFeatures  \
# 0                   None                   None
#
#                                   resoFacts.flooring  \
# 0  [Ceramic Tile, Vinyl, Carpet, Wall to Wall Car...
#
#   resoFacts.foundationDetails resoFacts.accessibilityFeatures  \
# 0           [Poured Concrete]                            None
#
#    resoFacts.hasGarage resoFacts.hasPetsAllowed resoFacts.bodyType  \
# 0                False                     None               None
#
#   resoFacts.topography resoFacts.landLeaseExpirationDate  \
# 0     Level,SteepSlope                              None
#
#    resoFacts.hasAdditionalParcels  resoFacts.waterViewYN  \
# 0                           False                   True
#
#                             resoFacts.atAGlanceFacts  \
# 0  [{'factLabel': 'Type', 'factValue': 'Single Fa...
#
#   resoFacts.offerReviewDate resoFacts.aboveGradeFinishedArea  \
# 0                      None                             None
#
#         resoFacts.view resoFacts.buyerAgencyCompensationType  \
# 0  [Bay, Canal, Sound]                                     %
#
#                                      resoFacts.rooms resoFacts.carportSpaces  \
# 0  [{'level': None, 'dimensions': None, 'features...                    None
#
#   resoFacts.cityRegion resoFacts.mainLevelBathrooms resoFacts.hasPrivatePool  \
# 0              Seattle                         None                     None
#
#   resoFacts.associationFeeIncludes       resoFacts.waterSource  \
# 0                             None  [Public, Company: Seattle]
#
#    resoFacts.coveredSpaces                    resoFacts.inclusions  \
# 0                        0  [Dishwasher, Refrigerator, StoveRange]
#
#    resoFacts.hasFireplace resoFacts.zoningDescription resoFacts.garageSpaces  \
# 0                   False                        None                   None
#
#                        resoFacts.sewer resoFacts.elevationUnits  \
# 0  [Sewer Connected, Company: Seattle]                     Feet
#
#   resoFacts.exclusions  resoFacts.mainLevelBedrooms  \
# 0                 None                            2
#
#   resoFacts.numberOfUnitsVacant resoFacts.hasWaterfrontView resoFacts.listAOR  \
# 0                          None                        None              None
#
#   resoFacts.lotSize resoFacts.entryLevel resoFacts.irrigationWaterRightsAcres  \
# 0        5,000 sqft                 None                                 None
#
#   resoFacts.greenWaterConservation  resoFacts.stories resoFacts.livingArea  \
# 0                             None                  1           1,900 sqft
#
#   resoFacts.numberOfUnitsInCommunity             resoFacts.listingTerms  \
# 0                               None  Cash Out,Conventional,FHA,VA Loan
#
#   resoFacts.otherStructures resoFacts.associationFee resoFacts.marketingType  \
# 0                      None                     None                    None
#
#   resoFacts.greenIndoorAirQuality resoFacts.greenSustainability  \
# 0                            None                          None
#
#    resoFacts.hasHomeWarranty resoFacts.associationPhone  \
# 0                      False                       None
#
#   resoFacts.greenBuildingVerificationType resoFacts.elementarySchool  \
# 0                                    None                       None
#
#    resoFacts.bedrooms resoFacts.architecturalStyle resoFacts.listingId  \
# 0                   5                         None                None
#
#   resoFacts.structureType resoFacts.interiorFeatures resoFacts.horseAmenities  \
# 0                   House                       None                     None
#
#             resoFacts.electric resoFacts.developmentStatus  \
# 0  [Company: Seattle Electric]                        None
#
#                                resoFacts.lotFeatures resoFacts.roofType  \
# 0  [Dead End Street, Paved, Cable TV, Deck, Fence...        Composition
#
#   resoFacts.waterSources resoFacts.constructionMaterials  \
# 0                   None                 [Wood Products]
#
#   resoFacts.fireplaceFeatures resoFacts.doorFeatures  \
# 0                        None                   None
#
#                       resoFacts.appliances  resoFacts.daysOnZillow  \
# 0  [Dishwasher, Refrigerator, Stove/Range]                     131
#
#   resoFacts.bathroomsPartial  resoFacts.bathroomsHalf  \
# 0                       None                        0
#
#   resoFacts.depositsAndFees  resoFacts.canRaiseHorses resoFacts.buildingName  \
# 0                      None                     False                   None
#
#   resoFacts.hasAssociation resoFacts.petsMaxWeight resoFacts.commonWalls  \
# 0                     None                    None                  None
#
#   resoFacts.totalActualRent resoFacts.additionalParcelsDescription  \
# 0                      None                                   None
#
#   resoFacts.associationName resoFacts.allowedPets resoFacts.communityFeatures  \
# 0                      None                  None                        None
#
#   resoFacts.tenantPays resoFacts.middleOrJuniorSchool  \
# 0                 None                           None
#
#   resoFacts.lotSizeDimensions resoFacts.roadSurfaceType  \
# 0                        None                      None
#
#    resoFacts.hasOpenParking  resoFacts.yearBuilt  \
# 0                     False                 1959
#
#   resoFacts.livingAreaRangeUnits  resoFacts.irrigationWaterRightsYN  \
# 0                           None                              False
#
#    resoFacts.bathroomsFull resoFacts.horseYN resoFacts.incomeIncludes  \
# 0                        2              None                     None
#
#   resoFacts.highSchool resoFacts.leaseTerm resoFacts.elevation  \
# 0                 None                None                None
#
#   resoFacts.cropsIncludedYN resoFacts.attic resoFacts.subdivisionName  \
# 0                      None            None              Pigeon Point
#
#   resoFacts.windowFeatures resoFacts.ownership resoFacts.woodedArea  \
# 0                     None                None                 None
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.associationPhone2  \
# 0                                   None                        None
#
#   resoFacts.buyerAgencyCompensation   resoFacts.heating  \
# 0                                 3  [Forced Air, Wall]
#
#   resoFacts.frontageLength resoFacts.virtualTourURLUnbranded  \
# 0                     None                              None
#
#   resoFacts.associationAmenities  resoFacts.propertySubType  \
# 0                           None  [Single Family Residence]
#
#    resoFacts.hasCooling resoFacts.belowGradeFinishedArea  \
# 0                  True                             None
#
#   resoFacts.hasElectricOnProperty resoFacts.foundationArea resoFacts.zoning  \
# 0                            None                     None             None
#
#   resoFacts.hoaFee resoFacts.livingAreaRange  resoFacts.basementYN  \
# 0             None                      None                 False
#
#   resoFacts.availabilityDate resoFacts.waterBodyName  \
# 0                       None                    None
#
#   resoFacts.waterfrontFeatures resoFacts.specialListingConditions  \
# 0                         None                           Standard
#
#   resoFacts.buildingAreaSource  resoFacts.taxAnnualAmount  resoFacts.parking  \
# 0                         None                       5980                  0
#
#    resoFacts.hasView resoFacts.virtualTour resoFacts.securityFeatures  \
# 0               True                  None                       None
#
#     resoFacts.cooling resoFacts.entryLocation resoFacts.levels  \
# 0  [Forced Air, Wall]                    None              One
#
#   resoFacts.ownershipType resoFacts.basement  resoFacts.onMarketDate  \
# 0                    None           Finished           1649721600000
#
#   resoFacts.waterView resoFacts.laundryFeatures  resoFacts.hasAttachedGarage  \
# 0     Bay,Canal,Sound                      None                        False
#
#   resoFacts.fencing resoFacts.spaFeatures  resoFacts.bathrooms  \
# 0              None                  None                    2
#
#   resoFacts.homeType resoFacts.isSeniorCommunity resoFacts.municipality  \
# 0       SingleFamily                        None                   None
#
#    resoFacts.bathroomsThreeQuarter  resoFacts.hasSpa resoFacts.otherParking  \
# 0                                0             False                   None
#
#   resoFacts.associationFee2 resoFacts.parcelNumber  resoFacts.hasHeating  \
# 0                      None             7547300800                  True
#
#   resoFacts.associationName2 resoFacts.hasRentControl  \
# 0                       None                     None
#
#   resoFacts.elementarySchoolDistrict resoFacts.otherEquipment  \
# 0                               None                     None
#
#   resoFacts.parkingFeatures resoFacts.buildingArea  resoFacts.furnished  \
# 0                    [None]                  1,900                False
#
#   resoFacts.vegetation resoFacts.patioAndPorchFeatures  \
# 0                 None                            None
#
#   resoFacts.buildingFeatures resoFacts.builderName  \
# 0                       None                  None
#
#   resoFacts.highSchoolDistrict resoFacts.propertyCondition  \
# 0                      Seattle                        None
#
#   resoFacts.storiesTotal resoFacts.yearBuiltEffective resoFacts.fireplaces  \
# 0                   None                         None                 None
#
#   resoFacts.bathroomsOneQuarter resoFacts.builderModel resoFacts.gas  \
# 0                          None                   None          None
#
#                                  resoFacts.utilities  \
# 0  [Cable Connected, High Speed Internet, Sewer C...
#
#   resoFacts.greenEnergyEfficient resoFacts.landLeaseAmount  \
# 0                           None                      None
#
#   resoFacts.isNewConstruction  resoFacts.hasLandLease  \
# 0                        None                   False
#
#    resoFacts.pricePerSquareFoot  resoFacts.hasCarport  \
# 0                           379                 False
#
#   resoFacts.openParkingSpaces  mortgageRates.arm5Rate  \
# 0                        None                   4.876
#
#    mortgageRates.fifteenYearFixedRate  mortgageRates.thirtyYearFixedRate  \
# 0                               4.719                              5.499
#
#   address.city address.neighborhood address.state address.streetAddress  \
# 0      Seattle                 None            WA   3830 18th Avenue SW
#
#   address.zipcode  listed_by.agent_reason  listed_by.zpro  \
# 0           98106                       3            True
#
#    listed_by.recent_sales  listed_by.review_count listed_by.display_name  \
# 0                       1                       9           Erin McNulty
#
#   listed_by.badge_type listed_by.business_name  listed_by.rating_average  \
# 0        Listing Agent       Four-U Realty Inc                         5
#
#   listed_by.phone.prefix listed_by.phone.areacode listed_by.phone.number  \
# 0                    525                      253                   5378
#
#             listed_by.zuid                                listed_by.image_url
# 0  X1-ZUwntcarytun0p_1wtuu  https://photos.zillowstatic.com/h_n/IS6a7qqncy...

# %%
df_property_detail['resoFacts.zoning'].iloc[0]

# %%
df = df_property_detail[['bedrooms', 'bathrooms', 'yearBuilt', 'homeType', 'resoFacts.livingArea', 
'resoFacts.lotSize', 'resoFacts.lotSizeDimensions', 'resoFacts.zoning', 'zestimate', 'rentZestimate']]

# %%
# Renaming columns 

df.rename(columns={"yearBuilt": "year_built"
                    , "homeType": "property_type"
                    , "resoFacts.livingArea":"living_area_sq_ft"
                    , "resoFacts.lotSize": "lot_size_sq_ft"
                    , "resoFacts.lotSizeDimensions":"lot_dimensions"
                    , "resoFacts.zoning":"zoning"
                    , "rentZestimate":"rent_zestimate"}, inplace=True)
# Out:
# /var/folders/07/925gqwkd6m7cm0c6dc9y49mw0000gs/T/ipykernel_16114/509113606.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"yearBuilt": "year_built"

# %%
print(df)
# Out:
#    bedrooms  bathrooms  year_built  property_type living_area_sq_ft  \
# 0         5          2        1959  SINGLE_FAMILY        1,900 sqft
#
#   lot_size_sq_ft lot_dimensions zoning  zestimate  rent_zestimate
# 0     5,000 sqft           None   None     774400            3200

# %% [markdown]
# # Above, changing the variable names so we formulate a dataframe for functions

# %%
# Take some of the variables that we are interested in


bedrooms = df_property_detail['bedrooms'].iloc[0] 
bathrooms = df_property_detail['bathrooms'].iloc[0] 
year_built = df_property_detail['yearBuilt'].iloc[0] 
property_type = df_property_detail['homeType'].iloc[0] 
living_area_sq_ft = df_property_detail['resoFacts.livingArea'].iloc[0] #
lot_size_sq_ft = df_property_detail['resoFacts.lotSize'].iloc[0] #
lot_dimensions = df_property_detail['resoFacts.lotSizeDimensions'].iloc[0] # 
zoning = df_property_detail['resoFacts.zoning'].iloc[0] # 

# estimates
zestimate = df_property_detail['zestimate'].iloc[0]
rent_zestimate = df_property_detail['rentZestimate'].iloc[0]

print('PROPERTY DETAILS FOR: ', property_address)
print('------------------------------------------------------------------')
print('  Bedrooms: {}'.format( bedrooms))
print('  Bathrooms: {}'.format( bathrooms))
print('  Year Built: {}'.format( year_built))
print('  Living Area: {}'.format(living_area_sq_ft))
print('  Lot Size: {}'.format( lot_size_sq_ft))
print('  Lot Dimensions: {}'.format( lot_dimensions))
print('  Zoning: {}'.format( zoning))
print('  Property Type: {}'.format( property_type))
print('  Zestimate: ${:,.0f}'.format( zestimate))
print('  Rent Zestimate: ${:,.0f}'.format( rent_zestimate))
# Out:
# PROPERTY DETAILS FOR:  3830 18th Avenue SW, Seattle, WA 98106
# ------------------------------------------------------------------
#   Bedrooms: 5
#   Bathrooms: 2
#   Year Built: 1959
#   Living Area: 1,900 sqft
#   Lot Size: 5,000 sqft
#   Lot Dimensions: None
#   Zoning: None
#   Property Type: SINGLE_FAMILY
#   Zestimate: $774,400
#   Rent Zestimate: $3,200

# %%
df =
# Out:
# numpy.int64

# %% [markdown]
# # I think... this is where I need to get creative

# %%
# To download file
# df_property_detail.to_csv('output.csv', index=False)
# files.download('output.csv')

# %% [markdown]
# # The next bit of code would be important if we decide to use [PropStream](https://trial.propstreampro.com/analyticsariel/) to pull in more data

# %%
# get file name
file_name = list(uploaded.keys())[0]

# read file
df_upload = pd.read_csv(io.BytesIO(uploaded[file_name]))
print('Num of rows:', len(df_upload))
df_upload.head()

# %%
# create empty list to store api response for property details
df_list = []
zpid_list = []

# iterate through dataframe
for index, row in df_upload.iterrows():
  # get property address attributes by column name
  street = row['Address']
  city = row['City']
  state = row['State']
  zip_code = "0" + str(row['Zip']) # fix issue with zip code

  # get zpid
  zpid = get_zpid(street=street, city=city, state=state, zip_code=zip_code)
  zpid_list.append(zpid)

  # wait 1 second to not overload Google Search
  time.sleep(1.5)

  # get property details
  # catch errors (possibly no zpid)
  try:
    response = get_property_detail(rapid_api_key, zpid)
    _df = pd.json_normalize(data=response.json())
    # append data to list of property details
    df_list.append(_df)
  except:
    print('Unable to retrieve data for : {0}, {1}, {2}, {3}'.format(street, city, state, zip_code))

# %%
# join property details data
df_prop_detail = pd.concat(df_list)
df_prop_detail.head()
